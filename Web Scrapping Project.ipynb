# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "https://www.worldometers.info/world-population/population-by-country/"

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text,"html")

# %%
print(soup.prettify())

# %%
soup.find("table")

# %%
world_columns = table.find_all("th")

# %%
world_column_titles = [columns.text for columns in world_columns]
print(world_column_titles)
# Out:
# ['#', 'Country (or dependency)', 'Population (2023)', 'Yearly Change', 'Net Change', 'Density (P/Km²)', 'Land Area (Km²)', 'Migrants (net)', 'Fert. Rate', 'Med. Age', 'Urban Pop %', 'World Share']

# %%
pd.DataFrame(columns = world_column_titles)

df
# Out:
#        # Country (or dependency) Population (2023) Yearly Change  Net Change  \
# 0      1                   India     1,428,627,663        0.81 %  11,454,490
# 1      2                   China     1,425,671,352       -0.02 %    -215,985
# 2      3           United States       339,996,563        0.50 %   1,706,706
# 3      4               Indonesia       277,534,122        0.74 %   2,032,783
# 4      5                Pakistan       240,485,658        1.98 %   4,660,796
# ..   ...                     ...               ...           ...         ...
# 230  231        Falkland Islands             3,791        0.29 %          11
# 231  232                    Niue             1,935        0.05 %           1
# 232  233                 Tokelau             1,893        1.18 %          22
# 233  234                Holy See               518        1.57 %           8
# 234  234                Holy See               518        1.57 %           8
#
#     Density (P/Km²) Land Area (Km²) Migrants (net) Fert. Rate Med. Age  \
# 0               481       2,973,190       -486,136        2.0       28
# 1               152       9,388,211       -310,220        1.2       39
# 2                37       9,147,420        999,700        1.7       38
# 3               153       1,811,570        -49,997        2.1       30
# 4               312         770,880       -165,988        3.3       21
# ..              ...             ...            ...        ...      ...
# 230               0          12,170              0        1.6       40
# 231               7             260              0        2.4       36
# 232             189              10              0        2.6       27
# 233           1,295               0              0
# 234           1,295               0              0
#
#     Urban Pop % World Share
# 0          36 %     17.76 %
# 1          65 %     17.72 %
# 2          83 %      4.23 %
# 3          59 %      3.45 %
# 4          35 %      2.99 %
# ..          ...         ...
# 230        62 %      0.00 %
# 231        41 %      0.00 %
# 232         0 %      0.00 %
# 233        N.A.      0.00 %
# 234        N.A.      0.00 %
#
# [235 rows x 12 columns]

# %%
table.find_all("td")

# %%
table.find_all("tr")

# %%
world_rows = table.find_all("tr")

# %%
for row in world_rows:
    row_data = row.find_all("td")
    individual_row_data = [data.text for data in row_data]
print(individual_row_data)
# Out:
# ['234', 'Holy See', '518', '1.57 %', '8', '1,295', '0', '0', '', '', 'N.A.', '0.00 %']

# %%
length = len(df)
df.loc[length] = individual_row_data

df
# Out:
#        # Country (or dependency) Population (2023) Yearly Change  Net Change  \
# 0      1                   India     1,428,627,663        0.81 %  11,454,490
# 1      2                   China     1,425,671,352       -0.02 %    -215,985
# 2      3           United States       339,996,563        0.50 %   1,706,706
# 3      4               Indonesia       277,534,122        0.74 %   2,032,783
# 4      5                Pakistan       240,485,658        1.98 %   4,660,796
# ..   ...                     ...               ...           ...         ...
# 231  232                    Niue             1,935        0.05 %           1
# 232  233                 Tokelau             1,893        1.18 %          22
# 233  234                Holy See               518        1.57 %           8
# 234  234                Holy See               518        1.57 %           8
# 235  234                Holy See               518        1.57 %           8
#
#     Density (P/Km²) Land Area (Km²) Migrants (net) Fert. Rate Med. Age  \
# 0               481       2,973,190       -486,136        2.0       28
# 1               152       9,388,211       -310,220        1.2       39
# 2                37       9,147,420        999,700        1.7       38
# 3               153       1,811,570        -49,997        2.1       30
# 4               312         770,880       -165,988        3.3       21
# ..              ...             ...            ...        ...      ...
# 231               7             260              0        2.4       36
# 232             189              10              0        2.6       27
# 233           1,295               0              0
# 234           1,295               0              0
# 235           1,295               0              0
#
#     Urban Pop % World Share
# 0          36 %     17.76 %
# 1          65 %     17.72 %
# 2          83 %      4.23 %
# 3          59 %      3.45 %
# 4          35 %      2.99 %
# ..          ...         ...
# 231        41 %      0.00 %
# 232         0 %      0.00 %
# 233        N.A.      0.00 %
# 234        N.A.      0.00 %
# 235        N.A.      0.00 %
#
# [236 rows x 12 columns]

# %%
df.to_csv(r"C:\Users\golez\OneDrive\Desktop\Portfolio\Python\WorldPopulation_Scrapped", index = False)
